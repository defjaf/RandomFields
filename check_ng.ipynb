# %%
% cd ~
import numpy as np
import realization as rn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/jaffe

# %%
kout, stats, hists = rn.ng.driver()

# %%
plt.plot(kout, stats.T[2])

# %%
stats.T
# Out:
# array([[ -2.09086730e-18,   8.42879637e-18,   2.53355491e-17,
#           1.36623962e-17,   9.98240034e-18,  -1.75990401e-19,
#          -1.98909863e-17,   2.24724394e-17,   2.43976451e-18],
#        [  1.00001549e+00,   1.00000225e+00,   1.00000083e+00,
#           1.00000043e+00,   1.00000026e+00,   1.00000021e+00,
#           1.00000032e+00,   1.00000093e+00,   1.00000837e+00],
#        [  4.43049189e-03,  -3.29719713e-03,  -5.88270163e-03,
#           1.06148047e-03,  -5.16069083e-04,   3.39908416e-04,
#           3.33980623e-03,   1.99656427e-03,  -4.75772446e-03],
#        [ -8.91263796e-03,  -1.58638384e-03,  -5.18333918e-03,
#           3.16938517e-03,   5.31381632e-04,  -3.01675790e-03,
#           3.58124016e-03,   2.06075703e-03,  -9.45088278e-03]])

# %%
plt.plot(hists[1][0], hists[1][1][1:])
plt.plot(hists[-1][0], hists[-1][1][1:])
