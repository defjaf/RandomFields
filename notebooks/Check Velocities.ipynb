# %%
import realization

# %%
class opts:
    npoints = 256
    nbar=500
    length = 100
    verr = 1000
    nonlin = 250
    plot = True

# %%
realization.velocities.main(opts)
# Out:
# # npoints=256 nbar=500 length= 100.0Mpc verr=1000.0km/s nonlin= 250.0km/s
# #dipole v_rms = 188.535057
# number with n==1: 488
# number with n>1: 0
# #    i        r    theta      phi      v_x      v_y      v_z      S_r
#      0    60.27   -33.43  -173.76    35.27   -45.75  -288.04   308.56
#      1    50.51     8.00   178.66   408.67    40.89   134.83   148.88
#      2    57.88   -23.04   159.84   260.12   297.44  -141.28 -2520.67
#      3    61.68   -18.08   147.79   117.75   -46.31    61.65 -1497.91
#      4    75.06   -26.92   137.84   130.52   178.69   -87.71   113.32
#      5    59.65   -17.53   149.91   -20.41   -72.01    31.04  1177.96
#      6    69.51    20.05  -138.39    82.46  -357.04   129.76  -425.27
#      7    57.37    -5.08  -148.70   301.82   101.19  -158.08  -397.29
#      8    67.74   -34.01  -150.40   330.18  -265.01   -92.04   240.88
#      9    79.49   -35.09   138.65   263.65  -110.44  -251.37  1560.11
# ...
