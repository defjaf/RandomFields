# %%
import realization

# %%
class opts:
    npoints = 256
    nbar=500
    length = 100
    verr = 1000
    nonlin = 250
    plot = True

# %%
# %matplotlib osx
realization.velocities.main(opts)
# Out:
# # npoints=256 nbar=500 length= 100.0Mpc verr=1000.0km/s nonlin= 250.0km/s
# #dipole v_rms = 188.535057
# number with n==1: 523
# number with n>1: 0
# #    i        r    theta      phi      v_x      v_y      v_z      S_r
#      0    69.48    -3.55  -136.14  -225.09   -72.82   348.78  -791.49
#      1    69.12    42.70  -169.81    14.14    81.14    78.86 -1503.74
#      2    54.32   -22.40   174.64   176.56  -100.53   140.37 -1601.41
#      3    60.48   -24.82   155.62  -165.67   138.71  -297.05    -2.74
#      4    73.36    33.26   144.59    26.77     7.96  -133.24   177.76
#      5    71.58    16.81  -136.39    18.68   -68.54    11.88 -1159.52
#      6    69.15   -15.40  -138.09   -25.12   -20.05   134.39  -649.18
#      7    59.37     3.39  -146.83   -67.94    38.00   137.42   300.04
#      8    68.68     8.17   136.86  -328.66   -23.57  -153.82   817.81
#      9    71.65    33.41  -145.38   -27.27   -74.32  -141.99    53.17
# ...
