# %%
import realization

# %%
class opts:
    npoints = 256
    nbar=500
    length = 100
    verr = 1000
    nonlin = 250
    plot = True

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
realization.velocities.main(opts)
# Out:
# # npoints=256 nbar=500 length= 100.0Mpc verr=1000.0km/s nonlin= 250.0km/s
# #dipole v_rms = 188.535057
# number with n==1: 485
# number with n>1: 0
# #    i        r    theta      phi      v_x      v_y      v_z      S_r
#      0    61.17    -2.20   144.89   139.08   132.66  -229.93   181.82
#      1    69.57    21.75  -140.15   111.66   274.76  -116.55  1485.89
#      2    64.02   -28.42  -150.95   373.98   322.01  -126.88  1003.55
#      3    57.67   -30.08  -170.54     5.88   329.64  -130.80   387.59
#      4    67.48    38.69   159.15   -62.58  -611.69   311.22  1093.35
#      5    59.97     4.11   145.38   172.25   172.05  -184.37 -1383.63
#      6    50.78    15.62   176.79  -440.39  -118.96    82.74  1174.48
#      7    78.03   -27.75  -134.54    -5.16  -106.85    16.03  -596.25
#      8    57.22    32.17   179.54  -427.52   -90.14   272.52   337.96
#      9    52.86   -24.44  -176.74    44.69   210.03    28.36 -1599.74
# ...
